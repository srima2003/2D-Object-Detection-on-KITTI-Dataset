# %%
# !pip install ultralytics

# %%
# %env WANDB_DISABLED=True
# Out:
# env: WANDB_DISABLED=True

# %%
from ultralytics import YOLO

# !yolo task=detect mode=train model='/kaggle/input/yolo-modified-yamlfile/yolov8modifiedmodel.yaml' data='/kaggle/input/yaml-file/data_kaggle.yaml' epochs=50 imgsz=640 mosaic=1.0 mixup=0.2 optimizer=Adam batch=16
# Out:
# Ultralytics YOLOv8.2.62 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !yolo task=detect mode=val model='/kaggle/working/runs/detect/train/weights/best.pt' data='/kaggle/input/yaml-file/data_kaggle.yaml'
# Out:
# Ultralytics YOLOv8.2.62 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla T4, 15095MiB)
# YOLOv8modifiedmodel summary (fused): 285 layers, 53,303,156 parameters, 0 gradients, 119.8 GFLOPs
# val: Scanning /kaggle/input/kitti-dataset-for-yolov8model/zDataset/Val/labels...
# val: WARNING ⚠️ Cache directory /kaggle/input/kitti-dataset-for-yolov8model/zDataset/Val is not writeable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        481       3087       0.73      0.664      0.718      0.492
#                    Car        421       1832      0.865      0.909      0.944      0.753
#             Pedistrian        107        224      0.791      0.643      0.726      0.404
#                    Van        140        173      0.829       0.84      0.879      0.674
#                Cyclist         61         83      0.745      0.739      0.824      0.529
# ...

# %%
# !yolo task=detect mode=predict model='/kaggle/working/runs/detect/train/weights/best.pt' conf=0.5 source='/kaggle/input/kitti-dataset-for-yolov8model/zDataset/testing/image_2'
# Out:
# Ultralytics YOLOv8.2.62 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla T4, 15095MiB)
# YOLOv8modifiedmodel summary (fused): 285 layers, 53,303,156 parameters, 0 gradients, 119.8 GFLOPs
#
# image 1/7518 /kaggle/input/kitti-dataset-for-yolov8model/zDataset/testing/image_2/000000.png: 256x640 1 Car, 95.8ms
# image 2/7518 /kaggle/input/kitti-dataset-for-yolov8model/zDataset/testing/image_2/000001.png: 256x640 3 Cars, 26.9ms
# image 3/7518 /kaggle/input/kitti-dataset-for-yolov8model/zDataset/testing/image_2/000002.png: 256x640 8 Cars, 26.8ms
# image 4/7518 /kaggle/input/kitti-dataset-for-yolov8model/zDataset/testing/image_2/000003.png: 256x640 3 Cars, 26.8ms
# image 5/7518 /kaggle/input/kitti-dataset-for-yolov8model/zDataset/testing/image_2/000004.png: 256x640 1 Car, 26.8ms
# image 6/7518 /kaggle/input/kitti-dataset-for-yolov8model/zDataset/testing/image_2/000005.png: 256x640 4 Cars, 26.8ms
# ...

# %%
cd /kaggle/working
# Out:
# /kaggle/working

# %%
# Zip the folder
# !zip -r /kaggle/working/runs.zip /kaggle/working/runs
# Out:
#   adding: kaggle/working/runs/ (stored 0%)
#   adding: kaggle/working/runs/detect/ (stored 0%)
#   adding: kaggle/working/runs/detect/train/ (stored 0%)
#   adding: kaggle/working/runs/detect/train/val_batch2_labels.jpg (deflated 11%)
#   adding: kaggle/working/runs/detect/train/labels.jpg (deflated 30%)
#   adding: kaggle/working/runs/detect/train/train_batch17520.jpg (deflated 21%)
#   adding: kaggle/working/runs/detect/train/args.yaml (deflated 53%)
#   adding: kaggle/working/runs/detect/train/R_curve.png (deflated 5%)
#   adding: kaggle/working/runs/detect/train/confusion_matrix.png (deflated 21%)
#   adding: kaggle/working/runs/detect/train/confusion_matrix_normalized.png (deflated 18%)
#   adding: kaggle/working/runs/detect/train/val_batch2_pred.jpg (deflated 11%)
#   adding: kaggle/working/runs/detect/train/F1_curve.png (deflated 5%)
#   adding: kaggle/working/runs/detect/train/val_batch1_labels.jpg (deflated 11%)
# ...
