# %%
# !pip install -q kaggle

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-844aadd3-9758-42b3-9242-93397162977e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-844aadd3-9758-42b3-9242-93397162977e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
! mkdir ~/.kaggle

# %%
# !cp kaggle.json ~/.kaggle/

# %%
# !chmod 600 ~/.kaggle/kaggle.json

# %%
! kaggle datasets list
# Out:
# ref                                                                 title                                               size  lastUpdated          downloadCount  voteCount  usabilityRating
# ------------------------------------------------------------------  -------------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# rabieelkharoua/students-performance-dataset                         📚 Students Performance Dataset 📚                    66KB  2024-06-12 23:09:20          10461        217  1.0
# nelgiriyewithana/most-streamed-spotify-songs-2024                   Most Streamed Spotify Songs 2024                   496KB  2024-06-15 18:50:51           8136        169  1.0
# dataanalyst001/world-population-by-country-2024                     World Population by country 2024                     6KB  2024-07-04 09:47:58            972         25  1.0
# ...

# %%
! kaggle datasets download -d velidesrimanaswini/kitti-dataset-for-yolov8model
# Out:
# Dataset URL: https://www.kaggle.com/datasets/velidesrimanaswini/kitti-dataset-for-yolov8model
# License(s): unknown
# ...
# 100% 11.5G/11.5G [02:44<00:00, 94.3MB/s]
# 100% 11.5G/11.5G [02:45<00:00, 74.8MB/s]

# %%
! unzip /content/kitti-dataset-for-yolov8model.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: zDataset/testing/image_2/002518.png
#   inflating: zDataset/testing/image_2/002519.png
#   inflating: zDataset/testing/image_2/002520.png
#   inflating: zDataset/testing/image_2/002521.png
#   inflating: zDataset/testing/image_2/002522.png
#   inflating: zDataset/testing/image_2/002523.png
#   inflating: zDataset/testing/image_2/002524.png
#   inflating: zDataset/testing/image_2/002525.png
#   inflating: zDataset/testing/image_2/002526.png
#   inflating: zDataset/testing/image_2/002527.png
#   inflating: zDataset/testing/image_2/002528.png
#   inflating: zDataset/testing/image_2/002529.png
#   inflating: zDataset/testing/image_2/002530.png
#   inflating: zDataset/testing/image_2/002531.png
#   inflating: zDataset/testing/image_2/002532.png
#   inflating: zDataset/testing/image_2/002533.png
#   inflating: zDataset/testing/image_2/002534.png
#   inflating: zDataset/testing/image_2/002535.png
# ...

# %%
# Clone the repository
# !git clone https://github.com/ultralytics/ultralytics
# %cd ultralytics

# Install the package
# !pip install -e .
# Out:
# Cloning into 'ultralytics'...
# remote: Enumerating objects: 29364, done.
# remote: Counting objects: 100% (1756/1756), done.
# remote: Compressing objects: 100% (1177/1177), done.
# remote: Total 29364 (delta 1045), reused 944 (delta 575), pack-reused 27608
# Receiving objects: 100% (29364/29364), 15.74 MiB | 25.46 MiB/s, done.
# Resolving deltas: 100% (20833/20833), done.
# /content/ultralytics
# Obtaining file:///content/ultralytics
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...

# %%
! nvidia-smi
# Out:
# Mon Jul  8 12:29:06 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   38C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
from ultralytics import YOLO

# !yolo task=detect mode=train model='/content/ultralytics/ultralytics/cfg/models/v8/yolov8m.yaml' data='/content/data.yaml' epochs=30 imgsz=640
# Out:
# Ultralytics YOLOv8.2.51 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=val model='/content/ultralytics/runs/detect/train3/weights/best.pt' data='/content/data.yaml'
# Out:
# Ultralytics YOLOv8.2.51 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8m summary (fused): 218 layers, 25844971 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /content/zDataset/Val/labels.cache... 481 images, 0 backgrounds, 0 corrupt: 100% 481/481 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 31/31 [00:13<00:00,  2.36it/s]
#                    all        481       3087      0.808      0.721      0.778      0.542
#                    Car        421       1832      0.929      0.903      0.957      0.774
#             Pedistrian        107        224      0.845      0.681      0.773      0.434
#                    Van        140        173       0.89      0.861      0.934      0.729
#                Cyclist         61         83      0.828      0.819      0.856      0.577
#                  Truck         52         57      0.933      0.982      0.986      0.791
# ...

# %%
# !yolo task=detect mode=predict model='/content/ultralytics/runs/detect/train3/weights/best.pt' conf=0.5 source='/content/zDataset/testing/image_2'
# Out:
# Streaming output truncated to the last 5000 lines.
# image 2522/7518 /content/zDataset/testing/image_2/002521.png: 224x640 1 Car, 17.4ms
# image 2523/7518 /content/zDataset/testing/image_2/002522.png: 224x640 1 Pedistrian, 17.3ms
# image 2524/7518 /content/zDataset/testing/image_2/002523.png: 224x640 3 Cars, 17.3ms
# image 2525/7518 /content/zDataset/testing/image_2/002524.png: 224x640 2 Cars, 17.4ms
# image 2526/7518 /content/zDataset/testing/image_2/002525.png: 224x640 1 Pedistrian, 17.4ms
# image 2527/7518 /content/zDataset/testing/image_2/002526.png: 224x640 5 Cars, 17.4ms
# image 2528/7518 /content/zDataset/testing/image_2/002527.png: 224x640 3 Cars, 17.4ms
# image 2529/7518 /content/zDataset/testing/image_2/002528.png: 224x640 3 Cars, 17.3ms
# image 2530/7518 /content/zDataset/testing/image_2/002529.png: 224x640 2 Cars, 17.4ms
# image 2531/7518 /content/zDataset/testing/image_2/002530.png: 224x640 1 Car, 17.4ms
# ...

# %%
# !zip -r runs.zip runs
# Out:
# Streaming output truncated to the last 5000 lines.
#   adding: runs/detect/predict/000212.png (deflated 0%)
#   adding: runs/detect/predict/005952.png (deflated 0%)
#   adding: runs/detect/predict/005335.png (deflated 0%)
#   adding: runs/detect/predict/004231.png (deflated 0%)
#   adding: runs/detect/predict/000009.png (deflated 0%)
#   adding: runs/detect/predict/007117.png (deflated 0%)
#   adding: runs/detect/predict/000452.png (deflated 0%)
#   adding: runs/detect/predict/001191.png (deflated 0%)
#   adding: runs/detect/predict/006256.png (deflated 0%)
#   adding: runs/detect/predict/006927.png (deflated 0%)
#   adding: runs/detect/predict/006625.png (deflated 0%)
#   adding: runs/detect/predict/005632.png (deflated 0%)
#   adding: runs/detect/predict/006023.png (deflated 0%)
#   adding: runs/detect/predict/002197.png (deflated 0%)
#   adding: runs/detect/predict/000992.png (deflated 0%)
#   adding: runs/detect/predict/002801.png (deflated 0%)
# ...

# %%
from google.colab import files
files.download('runs.zip')

# %%
from google.colab import drive

# Try mounting with force_remount=True to refresh credentials
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !cp -r runs /content/drive/MyDrive/
